# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Data scraping Exercise

# %% [markdown]
# ## Starting Point
#
# As an all-time favorite game of mine since forever, I was extremely happy when I found that there is a database website for all things concerning Diablo IV. Thus, the idea for this mini exercise was born.
#
# The website that is scraped is [Diablo IV](https://diablo4.cc).
#
# ### First Things First - Check the Permissions
#
# The `robots.txt` file at `https://diablo4.cc/robots.txt` provides information about what can and cannot be scraped. In this case, everything is allowed:
#
# ```plaintext
# User-agent: *
# Allow: /

# %% [markdown]
# ### Axes
#
# Let's first concentrate on axes

# %%
diablo4_axes = requests.get("https://diablo4.cc/Axe")
parser = BeautifulSoup(diablo4_axes.content, "html.parser")

# %%
rows = parser.find_all("div",class_= "row row-cols-1 row-cols-lg-3 g-2")

# %%
rows
# Out:
# [<div class="row row-cols-1 row-cols-lg-3 g-2"><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/35197504.webp")'></div>
#  <div class="card-body"><div><a class="c_unique text-decoration-none item-name" data-hover="?s=Item/1306219" href="Waxing_Gibbous">Waxing Gibbous</a></div><div class="c_unique item-type">Unique Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><li class="empty-bullet">+[14 – 21]% Critical Strike Damage</li><li class="empty-bullet">+[16.5 – 23.5]% Damage to Close Enemies</li><li class="empty-bullet">+[21 – 35]% Damage to Injured Enemies</li><li class="empty-bullet">+[1 – 2] Spirit On Kill</li><li class="c_unique">Gain <span class="c_important"><u>Stealth</u></span> for <span class="c_number"><u>2</u></span> seconds when killing enemies with <span class="c_important">Shred</span>. Breaking <span class="c_important"><u>Stealth</u></span> with an attack grants Ambush which guarantees Critical Strikes for <span class="c_random">[1 – 2.5]</span> seconds.(Druid Only)</li><div class="flavor">The nights preceding the full moon are sometimes far more dangerous than the event itself. The frenzy has begun to rise, yet the night is just dark enough to obscure a hunter from their prey's sight.</div><div class="text-end text-white-50">Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/35197506.webp")'></div>
#  <div class="card-body"><div><a class="c_unique text-decoration-none item-name" data-hover="?s=Item/223287" href="The_Butcher%27s_Cleaver">The Butcher's Cleaver</a></div><div class="c_unique item-type">Unique Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><li class="empty-bullet">+[10.5 – 17.5]% Physical Damage</li><li class="empty-bullet">+[17.5 – 31.5]% Damage to Crowd Controlled Enemies</li><li class="empty-bullet">+[14 – 21]% Critical Strike Damage</li><li class="empty-bullet">+[4.5 – 12]% Critical Strike Chance Against Injured Enemies</li><li class="c_unique"><span class="c_label">Lucky Hit:</span> When you Critically Strike an enemy you have up to a <span class="c_number">100%</span> chance to Fear and Slow them by <span class="c_random">[61 – 75]%</span> for <span class="c_number">4</span> seconds.</li><div class="flavor">A nightmarish amalgam of blood, bone and steel, this axe is as horrific, and as deadly, as its creator.</div><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/35197499.webp")'></div>
#  <div class="card-body"><div><a class="c_legendary text-decoration-none item-name" data-hover="?s=Item/591438" href="Bearded_Axe">Bearded Axe</a></div><div class="c_legendary item-type">Legendary Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/35197500.webp")'></div>
#  <div class="card-body"><div><a class="c_legendary text-decoration-none item-name" data-hover="?s=Item/592216" href="Marauder_Axe">Marauder Axe</a></div><div class="c_legendary item-type">Legendary Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/35197501.webp")'></div>
#  <div class="card-body"><div><a class="c_legendary text-decoration-none item-name" data-hover="?s=Item/592219" href="Bullova">Bullova</a></div><div class="c_legendary item-type">Legendary Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/35197502.webp")'></div>
#  <div class="card-body"><div><a class="c_legendary text-decoration-none item-name" data-hover="?s=Item/1306998" href="Ravager">Ravager</a></div><div class="c_legendary item-type">Legendary Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/35197503.webp")'></div>
#  <div class="card-body"><div><a class="c_legendary text-decoration-none item-name" data-hover="?s=Item/1267098" href="Snake_Axe">Snake Axe</a></div><div class="c_legendary item-type">Legendary Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/35197505.webp")'></div>
#  <div class="card-body"><div><a class="c_legendary text-decoration-none item-name" data-hover="?s=Item/1267102" href="Octopian_Edge">Octopian Edge</a></div><div class="c_legendary item-type">Legendary Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521657.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/207032" href="Axe">Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521657.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/132723" href="Hand_Axe">Hand Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521657.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/143272" href="Great_Axe">Great Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521657.webp")'></div>
#  <div class="card-body"><div><a class="c_magic text-decoration-none item-name" data-hover="?s=Item/446358" href="Cutter%27s_Axe">Cutter's Axe</a></div><div class="c_magic item-type">Magic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521656.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1321912" href="Hand_Axe">Hand Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521659.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/603481" href="War_Axe">War Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><li class="empty-bullet">+[0.02 – 0.048] Life On Kill</li><li class="empty-bullet">+[16.5 – 23.5]% Damage to Elites</li><li class="empty-bullet"><span class="c_label">Lucky Hit:</span> Up to a +[4.4 – 10]% Chance to Execute Injured Non-Elites</li><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521659.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/449951" href="Cleaver">Cleaver</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366865.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1046306" href="Axe">Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521659.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/459947" href="Military_Pick">Military Pick</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366866.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/459948" href="Twin_Axe">Twin Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366867.webp")'></div>
#  <div class="card-body"><div><a class="c_rare text-decoration-none item-name" data-hover="?s=Item/459949" href="Broad_Axe">Broad Axe</a></div><div class="c_rare item-type">Rare Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366868.webp")'></div>
#  <div class="card-body"><div><a class="c_rare text-decoration-none item-name" data-hover="?s=Item/459950" href="Battle_Axe">Battle Axe</a></div><div class="c_rare item-type">Rare Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366869.webp")'></div>
#  <div class="card-body"><div><a class="c_rare text-decoration-none item-name" data-hover="?s=Item/784817" href="Combat_Hatchet">Combat Hatchet</a></div><div class="c_rare item-type">Rare Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366865.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/450499" href="Axe">Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366866.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/460008" href="Double_Axe">Double Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366867.webp")'></div>
#  <div class="card-body"><div><a class="c_rare text-decoration-none item-name" data-hover="?s=Item/460009" href="Crowbill">Crowbill</a></div><div class="c_rare item-type">Rare Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366868.webp")'></div>
#  <div class="card-body"><div><a class="c_rare text-decoration-none item-name" data-hover="?s=Item/460010" href="War_Crescent">War Crescent</a></div><div class="c_rare item-type">Rare Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3630366869.webp")'></div>
#  <div class="card-body"><div><a class="c_rare text-decoration-none item-name" data-hover="?s=Item/784816" href="Combat_Hatchet">Combat Hatchet</a></div><div class="c_rare item-type">Rare Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521658.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1275194" href="Ceder_Wood_Axe">Ceder Wood Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521659.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/143273" href="War_Axe">War Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521660.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/143274" href="Broad_Axe">Broad Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521661.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/166562" href="Ripper_Axe">Ripper Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521662.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/338566" href="Battle_Axe">Battle Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_PH_Hibernal_Solstice/987825239.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1624200" href="Midwinter_Tomahawk">Midwinter Tomahawk</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_PH_Ursa_Noctua/236735287.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1268006" href="Iron_Beak">Iron Beak</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_HArmor_dru_stor158/3115512664.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1561185" href="Hell_Hatchet">Hell Hatchet</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_PH_Undying_Rage/236735289.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1402518" href="Skullcleave">Skullcleave</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_HArmor_bar_stor158/3115512667.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1407079" href="Debt">Debt</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_PH_Starter_Pack_001/236735293.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1277656" href="Protean_Axe">Protean Axe</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_PH_Spirit_Captor/236735324.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1492910" href="Coldiron_Sagaris">Coldiron Sagaris</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_HArmor_dru_stor183/236735351.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1588626" href="Crescent_Arc">Crescent Arc</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_S02_Battlepass/236735354.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1576255" href="Ensanguined_Marrow_Battle_Axe">Ensanguined Marrow Battle Axe</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1101201" href="Hand_Axe">Hand Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/338231" href="Axe">Axe</a></div><div class="item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><li class="empty-bullet">+28% Damage to Healthy Enemies</li><hr class="clearfix separator"/><div class="text-end text-white-50">Barbarian</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_HArmor_dru_stor160/236735290.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1449851" href="Tail_Chopper">Tail Chopper</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_PH_Liliths_gifts/3115512668.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1284286" href="Hell-Lava_Pearl_Splitter">Hell-Lava Pearl Splitter</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_BattlePass_001/3115512701.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1493597" href="Balanced_Axe">Balanced Axe</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_PH_Twitch_Axe/236735326.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1364185" href="Azurehand_Head-cleaver">Azurehand Head-cleaver</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_HArmor_bar_stor188/3115512703.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1599211" href="Merciless_Totem">Merciless Totem</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_Weapons_bar_stor001/236735353.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1599388" href="Klath-Ulna%27s_Cut">Klath-Ulna's Cut</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_HArmor_bar_stor201/3115512731.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1647972" href="Bloody_Winged_Axe">Bloody Winged Axe</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_BattlePass_003/3115512734.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1641293" href="Spheral_Broad_Axe">Spheral Broad Axe</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Bundle_BattlePass_004/3115512762.webp")'></div>
#  <div class="card-body"><div><a class="text-decoration-none item-name" data-hover="?s=Item/1751975" href="Demigod_Hewer">Demigod Hewer</a></div><div class="item-type">Cosmetic Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian, Druid</div></div>
#  </div>
#  </div><div class="col">
#  <div class="d-flex border rounded" style="position: relative">
#  <div class="header-icon" style='background-image: url("https://cdn.diablo4.cc/image/texture/2DInventory_Axes/3571521657.webp")'></div>
#  <div class="card-body"><div><a class="c_set text-decoration-none item-name" data-hover="?s=Item/603103" href="Hand_Axe">Hand Axe</a></div><div class="c_set item-type"> Axe</div><div>925 Item Power</div><hr class="half-width separator"/><div class="damage">1,838 Damage Per Second</div><ul class="damage-details"><li>[1,337 – 2,005] Damage per Hit</li><li>1.10 Attacks per Second (Fast)</li></ul><div class="text-end text-white-50">Barbarian</div></div>
#  </div>
#  </div></div>]

# %%
rows = parser.find_all("div",class_= "row row-cols-1 row-cols-lg-3 g-2")
# Extracting data from each row
for row in rows:
    cols = row.find_all('div', class_='col')
    for col in cols:
        item_name_elem = col.find('a', class_='item-name')
        item_type_elem = col.find('div', class_='item-type')
        item_power_elem = col.find('div', string=lambda x: 'Item Power' in x if x else False)
        damage_per_second_elem = col.find('div', class_='damage')
        
        item_name = item_name_elem.text.strip() if item_name_elem else 'N/A'
        item_type = item_type_elem.text.strip() if item_type_elem else 'N/A'
        item_power = item_power_elem.text.strip() if item_power_elem else 'N/A'
        damage_per_second = damage_per_second_elem.text.strip() if damage_per_second_elem else 'N/A'
        
        # Collecting all details into a dictionary
        d4axes = {
            'Name': item_name,
            'Type': item_type,
            'Item Power': item_power,
            'Damage per Second': damage_per_second
        }
        
        # Print the details
        print(d4axes)
# Out:
# {'Name': 'Waxing Gibbous', 'Type': 'Unique Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': "The Butcher's Cleaver", 'Type': 'Unique Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Bearded Axe', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Marauder Axe', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Bullova', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Ravager', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Snake Axe', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Octopian Edge', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hand Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Great Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': "Cutter's Axe", 'Type': 'Magic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hand Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'War Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Cleaver', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Military Pick', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Twin Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Broad Axe', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Battle Axe', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Combat Hatchet', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Double Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Crowbill', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'War Crescent', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Combat Hatchet', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Ceder Wood Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'War Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Broad Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Ripper Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Battle Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Midwinter Tomahawk', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Iron Beak', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hell Hatchet', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Skullcleave', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Debt', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Protean Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Coldiron Sagaris', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Crescent Arc', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Ensanguined Marrow Battle Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hand Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Tail Chopper', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hell-Lava Pearl Splitter', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Balanced Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Azurehand Head-cleaver', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Merciless Totem', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': "Klath-Ulna's Cut", 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Bloody Winged Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Spheral Broad Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Demigod Hewer', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hand Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}

# %% [markdown]
# we get inidividual lines, we need to fix the code to have them in a list

# %%
# Fetch the page content
url = 'https://diablo4.cc/Axe'
response = requests.get(url)
if response.status_code != 200:
    raise Exception(f"Failed to load page {url}")

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find all rows
rows = soup.find_all("div", class_="row row-cols-1 row-cols-lg-3 g-2")

# Initialize an empty list to hold the dictionaries
d4axes_list = []

# Extracting data from each row
for row in rows:
    cols = row.find_all('div', class_='col')
    for col in cols:
        item_name_elem = col.find('a', class_='item-name')
        item_type_elem = col.find('div', class_='item-type')
        item_power_elem = col.find('div', string=lambda x: 'Item Power' in x if x else False)
        damage_per_second_elem = col.find('div', class_='damage')
        
        item_name = item_name_elem.text.strip() if item_name_elem else 'N/A'
        item_type = item_type_elem.text.strip() if item_type_elem else 'N/A'
        item_power = item_power_elem.text.strip() if item_power_elem else 'N/A'
        damage_per_second = damage_per_second_elem.text.strip() if damage_per_second_elem else 'N/A'
        
        # Collecting all details into a dictionary
        d4axes = {
            'Name': item_name,
            'Type': item_type,
            'Item Power': item_power,
            'Damage per Second': damage_per_second
        }
        
        # Append the dictionary to the list
        d4axes_list.append(d4axes)

# Print the list of dictionaries
for axe in d4axes_list:
    print(axe)

# Optional: Convert the list of dictionaries to a DataFrame
d4axes_data = pd.DataFrame(d4axes_list)
print(d4axes_data)
# Out:
# {'Name': 'Waxing Gibbous', 'Type': 'Unique Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': "The Butcher's Cleaver", 'Type': 'Unique Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Bearded Axe', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Marauder Axe', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Bullova', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Ravager', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Snake Axe', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Octopian Edge', 'Type': 'Legendary Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hand Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Great Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': "Cutter's Axe", 'Type': 'Magic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hand Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'War Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Cleaver', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Military Pick', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Twin Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Broad Axe', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Battle Axe', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Combat Hatchet', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Double Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Crowbill', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'War Crescent', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Combat Hatchet', 'Type': 'Rare Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Ceder Wood Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'War Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Broad Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Ripper Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Battle Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Midwinter Tomahawk', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Iron Beak', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hell Hatchet', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Skullcleave', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Debt', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Protean Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Coldiron Sagaris', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Crescent Arc', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Ensanguined Marrow Battle Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hand Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Tail Chopper', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hell-Lava Pearl Splitter', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Balanced Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Azurehand Head-cleaver', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Merciless Totem', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': "Klath-Ulna's Cut", 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Bloody Winged Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Spheral Broad Axe', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Demigod Hewer', 'Type': 'Cosmetic Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
# {'Name': 'Hand Axe', 'Type': 'Axe', 'Item Power': '925 Item Power', 'Damage per Second': '1,838 Damage Per Second'}
#                              Name           Type      Item Power  \
# 0                  Waxing Gibbous     Unique Axe  925 Item Power
# 1           The Butcher's Cleaver     Unique Axe  925 Item Power
# 2                     Bearded Axe  Legendary Axe  925 Item Power
# 3                    Marauder Axe  Legendary Axe  925 Item Power
# 4                         Bullova  Legendary Axe  925 Item Power
# 5                         Ravager  Legendary Axe  925 Item Power
# 6                       Snake Axe  Legendary Axe  925 Item Power
# 7                   Octopian Edge  Legendary Axe  925 Item Power
# 8                             Axe            Axe  925 Item Power
# 9                        Hand Axe            Axe  925 Item Power
# 10                      Great Axe            Axe  925 Item Power
# 11                   Cutter's Axe      Magic Axe  925 Item Power
# 12                       Hand Axe            Axe  925 Item Power
# 13                        War Axe            Axe  925 Item Power
# 32  1,838 Damage Per Second
# 33  1,838 Damage Per Second
# 34  1,838 Damage Per Second
# 35  1,838 Damage Per Second
# 36  1,838 Damage Per Second
# 37  1,838 Damage Per Second
# 38  1,838 Damage Per Second
# 39  1,838 Damage Per Second
# 40  1,838 Damage Per Second
# 41  1,838 Damage Per Second
# 42  1,838 Damage Per Second
# 43  1,838 Damage Per Second
# 44  1,838 Damage Per Second
# 45  1,838 Damage Per Second
# 46  1,838 Damage Per Second
# 47  1,838 Damage Per Second
# 48  1,838 Damage Per Second
# 49  1,838 Damage Per Second
# 50  1,838 Damage Per Second
# 51  1,838 Damage Per Second

# %%
# Fetch the page content
url = 'https://diablo4.cc/Axe'
response = requests.get(url)
if response.status_code != 200:
    raise Exception(f"Failed to load page {url}")

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find all rows
rows = soup.find_all("div", class_="row row-cols-1 row-cols-lg-3 g-2")

# Initialize an empty list to hold the dictionaries
d4axes_list = []

# Extracting data from each row
for row in rows:
    cols = row.find_all('div', class_='col')
    for col in cols:
        item_name_elem = col.find('a', class_='item-name')
        item_type_elem = col.find('div', class_='item-type')
        item_power_elem = col.find('div', string=lambda x: 'Item Power' in x if x else False)
        damage_per_second_elem = col.find('div', class_='damage')
        
        item_name = item_name_elem.text.strip() if item_name_elem else 'N/A'
        item_type = item_type_elem.text.strip() if item_type_elem else 'N/A'
        item_power = item_power_elem.text.strip() if item_power_elem else 'N/A'
        damage_per_second = damage_per_second_elem.text.strip() if damage_per_second_elem else 'N/A'
        
        # Extract additional damage details
        damage_details_elem = col.find('ul', class_='damage-details')
        if damage_details_elem:
            damage_details = [li.text.strip() for li in damage_details_elem.find_all('li')]
        else:
            damage_details = ['N/A', 'N/A']
        
        # Collecting all details into a dictionary
        d4axes = {
            'Name': item_name,
            'Type': item_type,
            'Item Power': item_power,
            'Damage per Second': damage_per_second,
            'Damage per Hit': damage_details[0] if len(damage_details) > 0 else 'N/A',
            'Attacks per Second': damage_details[1] if len(damage_details) > 1 else 'N/A'
        }
        
        # Append the dictionary to the list
        d4axes_list.append(d4axes)

# Convert the list of dictionaries to a DataFrame
d4axes_data = pd.DataFrame(d4axes_list)

# Display the DataFrame
print(d4axes_data)
# Out:
#                              Name           Type      Item Power  \
# 0                  Waxing Gibbous     Unique Axe  925 Item Power
# 1           The Butcher's Cleaver     Unique Axe  925 Item Power
# 2                     Bearded Axe  Legendary Axe  925 Item Power
# 3                    Marauder Axe  Legendary Axe  925 Item Power
# 4                         Bullova  Legendary Axe  925 Item Power
# 5                         Ravager  Legendary Axe  925 Item Power
# 6                       Snake Axe  Legendary Axe  925 Item Power
# 7                   Octopian Edge  Legendary Axe  925 Item Power
# 8                             Axe            Axe  925 Item Power
# 9                        Hand Axe            Axe  925 Item Power
# 10                      Great Axe            Axe  925 Item Power
# 11                   Cutter's Axe      Magic Axe  925 Item Power
# 12                       Hand Axe            Axe  925 Item Power
# 13                        War Axe            Axe  925 Item Power
# 14                        Cleaver            Axe  925 Item Power
# 15                            Axe            Axe  925 Item Power
# 15  1.10 Attacks per Second (Fast)
# 16  1.10 Attacks per Second (Fast)
# 17  1.10 Attacks per Second (Fast)
# 18  1.10 Attacks per Second (Fast)
# 19  1.10 Attacks per Second (Fast)
# 20  1.10 Attacks per Second (Fast)
# 21  1.10 Attacks per Second (Fast)
# 22  1.10 Attacks per Second (Fast)
# 23  1.10 Attacks per Second (Fast)
# 24  1.10 Attacks per Second (Fast)
# 25  1.10 Attacks per Second (Fast)
# 26  1.10 Attacks per Second (Fast)
# 27  1.10 Attacks per Second (Fast)
# 28  1.10 Attacks per Second (Fast)
# 29  1.10 Attacks per Second (Fast)
# 30  1.10 Attacks per Second (Fast)
# 31  1.10 Attacks per Second (Fast)
# 32  1.10 Attacks per Second (Fast)
# 33  1.10 Attacks per Second (Fast)
# 34  1.10 Attacks per Second (Fast)
# 35  1.10 Attacks per Second (Fast)
# 36  1.10 Attacks per Second (Fast)
# 37  1.10 Attacks per Second (Fast)
# 38  1.10 Attacks per Second (Fast)
# 39  1.10 Attacks per Second (Fast)
# 40  1.10 Attacks per Second (Fast)
# 41  1.10 Attacks per Second (Fast)
# 42  1.10 Attacks per Second (Fast)
# 43  1.10 Attacks per Second (Fast)
# 44  1.10 Attacks per Second (Fast)
# 45  1.10 Attacks per Second (Fast)
# 46  1.10 Attacks per Second (Fast)
# 47  1.10 Attacks per Second (Fast)
# 48  1.10 Attacks per Second (Fast)
# 49  1.10 Attacks per Second (Fast)
# 50  1.10 Attacks per Second (Fast)
# 51  1.10 Attacks per Second (Fast)

# %%
d4axes_data.to_csv('d4axes_data.csv', index=False)

# %%
d4axes_data
# Out:
#                              Name           Type      Item Power  \
# 0                  Waxing Gibbous     Unique Axe  925 Item Power
# 1           The Butcher's Cleaver     Unique Axe  925 Item Power
# 2                     Bearded Axe  Legendary Axe  925 Item Power
# 3                    Marauder Axe  Legendary Axe  925 Item Power
# 4                         Bullova  Legendary Axe  925 Item Power
# 5                         Ravager  Legendary Axe  925 Item Power
# 6                       Snake Axe  Legendary Axe  925 Item Power
# 7                   Octopian Edge  Legendary Axe  925 Item Power
# 8                             Axe            Axe  925 Item Power
# 9                        Hand Axe            Axe  925 Item Power
# 10                      Great Axe            Axe  925 Item Power
# 11                   Cutter's Axe      Magic Axe  925 Item Power
# 12                       Hand Axe            Axe  925 Item Power
# 13                        War Axe            Axe  925 Item Power
# 14                        Cleaver            Axe  925 Item Power
# 15                            Axe            Axe  925 Item Power
# 16                  Military Pick            Axe  925 Item Power
# 17                       Twin Axe            Axe  925 Item Power
# 18                      Broad Axe       Rare Axe  925 Item Power
# 19                     Battle Axe       Rare Axe  925 Item Power
# 20                 Combat Hatchet       Rare Axe  925 Item Power
# 21                            Axe            Axe  925 Item Power
# 22                     Double Axe            Axe  925 Item Power
# 23                       Crowbill       Rare Axe  925 Item Power
# 24                   War Crescent       Rare Axe  925 Item Power
# 25                 Combat Hatchet       Rare Axe  925 Item Power
# 26                 Ceder Wood Axe            Axe  925 Item Power
# 27                        War Axe            Axe  925 Item Power
# 29  1.10 Attacks per Second (Fast)
# 30  1.10 Attacks per Second (Fast)
# 31  1.10 Attacks per Second (Fast)
# 32  1.10 Attacks per Second (Fast)
# 33  1.10 Attacks per Second (Fast)
# 34  1.10 Attacks per Second (Fast)
# 35  1.10 Attacks per Second (Fast)
# 36  1.10 Attacks per Second (Fast)
# 37  1.10 Attacks per Second (Fast)
# 38  1.10 Attacks per Second (Fast)
# 39  1.10 Attacks per Second (Fast)
# 40  1.10 Attacks per Second (Fast)
# 41  1.10 Attacks per Second (Fast)
# 42  1.10 Attacks per Second (Fast)
# 43  1.10 Attacks per Second (Fast)
# 44  1.10 Attacks per Second (Fast)
# 45  1.10 Attacks per Second (Fast)
# 46  1.10 Attacks per Second (Fast)
# 47  1.10 Attacks per Second (Fast)
# 48  1.10 Attacks per Second (Fast)
# 49  1.10 Attacks per Second (Fast)
# 50  1.10 Attacks per Second (Fast)
# 51  1.10 Attacks per Second (Fast)

# %% [markdown]
# ### now to remove the unnecessary strings

# %%
d4axes_data['Item Power'] = d4axes_data['Item Power'].str.replace(' Item Power', '')

# %%
d4axes_data
# Out:
#                              Name           Type Item Power  \
# 0                  Waxing Gibbous     Unique Axe        925
# 1           The Butcher's Cleaver     Unique Axe        925
# 2                     Bearded Axe  Legendary Axe        925
# 3                    Marauder Axe  Legendary Axe        925
# 4                         Bullova  Legendary Axe        925
# 5                         Ravager  Legendary Axe        925
# 6                       Snake Axe  Legendary Axe        925
# 7                   Octopian Edge  Legendary Axe        925
# 8                             Axe            Axe        925
# 9                        Hand Axe            Axe        925
# 10                      Great Axe            Axe        925
# 11                   Cutter's Axe      Magic Axe        925
# 12                       Hand Axe            Axe        925
# 13                        War Axe            Axe        925
# 14                        Cleaver            Axe        925
# 15                            Axe            Axe        925
# 16                  Military Pick            Axe        925
# 17                       Twin Axe            Axe        925
# 18                      Broad Axe       Rare Axe        925
# 19                     Battle Axe       Rare Axe        925
# 20                 Combat Hatchet       Rare Axe        925
# 21                            Axe            Axe        925
# 22                     Double Axe            Axe        925
# 23                       Crowbill       Rare Axe        925
# 24                   War Crescent       Rare Axe        925
# 25                 Combat Hatchet       Rare Axe        925
# 26                 Ceder Wood Axe            Axe        925
# 27                        War Axe            Axe        925
# 28                      Broad Axe            Axe        925
# 29                     Ripper Axe            Axe        925
# 30                     Battle Axe            Axe        925
# 31             Midwinter Tomahawk            Axe        925
# 32                      Iron Beak   Cosmetic Axe        925
# 33                   Hell Hatchet   Cosmetic Axe        925
# 34                    Skullcleave   Cosmetic Axe        925
# 35                           Debt   Cosmetic Axe        925
# 36                    Protean Axe   Cosmetic Axe        925
# 37               Coldiron Sagaris   Cosmetic Axe        925
# 38                   Crescent Arc   Cosmetic Axe        925
# 39  Ensanguined Marrow Battle Axe   Cosmetic Axe        925
# 40                       Hand Axe            Axe        925
# 41                            Axe            Axe        925
# 42                   Tail Chopper   Cosmetic Axe        925
# 43       Hell-Lava Pearl Splitter   Cosmetic Axe        925
# 44                   Balanced Axe   Cosmetic Axe        925
# 45         Azurehand Head-cleaver   Cosmetic Axe        925
# 46                Merciless Totem   Cosmetic Axe        925
# 47               Klath-Ulna's Cut   Cosmetic Axe        925
# 48              Bloody Winged Axe   Cosmetic Axe        925
# 49              Spheral Broad Axe   Cosmetic Axe        925
# 50                  Demigod Hewer   Cosmetic Axe        925
# 51                       Hand Axe            Axe        925
#
#           Damage per Second                  Damage per Hit  \
# 0   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 1   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 2   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 3   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 4   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 5   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 6   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 7   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 8   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 9   1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 10  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 11  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 12  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 13  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 14  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 15  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 16  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 17  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 18  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 19  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 20  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 21  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 22  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 23  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 24  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 25  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 26  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 27  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 28  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 29  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 30  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 31  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 32  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 33  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 34  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 35  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 36  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 37  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 38  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 39  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 40  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 41  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 42  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 43  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 44  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 45  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 46  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 47  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 48  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 49  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 50  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
# 51  1,838 Damage Per Second  [1,337 – 2,005] Damage per Hit
#
#                 Attacks per Second
# 0   1.10 Attacks per Second (Fast)
# 1   1.10 Attacks per Second (Fast)
# 2   1.10 Attacks per Second (Fast)
# 3   1.10 Attacks per Second (Fast)
# 4   1.10 Attacks per Second (Fast)
# 5   1.10 Attacks per Second (Fast)
# 6   1.10 Attacks per Second (Fast)
# 7   1.10 Attacks per Second (Fast)
# 8   1.10 Attacks per Second (Fast)
# 9   1.10 Attacks per Second (Fast)
# 10  1.10 Attacks per Second (Fast)
# 11  1.10 Attacks per Second (Fast)
# 12  1.10 Attacks per Second (Fast)
# 13  1.10 Attacks per Second (Fast)
# 14  1.10 Attacks per Second (Fast)
# 15  1.10 Attacks per Second (Fast)
# 16  1.10 Attacks per Second (Fast)
# 17  1.10 Attacks per Second (Fast)
# 18  1.10 Attacks per Second (Fast)
# 19  1.10 Attacks per Second (Fast)
# 20  1.10 Attacks per Second (Fast)
# 21  1.10 Attacks per Second (Fast)
# 22  1.10 Attacks per Second (Fast)
# 23  1.10 Attacks per Second (Fast)
# 24  1.10 Attacks per Second (Fast)
# 25  1.10 Attacks per Second (Fast)
# 26  1.10 Attacks per Second (Fast)
# 27  1.10 Attacks per Second (Fast)
# 28  1.10 Attacks per Second (Fast)
# 29  1.10 Attacks per Second (Fast)
# 30  1.10 Attacks per Second (Fast)
# 31  1.10 Attacks per Second (Fast)
# 32  1.10 Attacks per Second (Fast)
# 33  1.10 Attacks per Second (Fast)
# 34  1.10 Attacks per Second (Fast)
# 35  1.10 Attacks per Second (Fast)
# 36  1.10 Attacks per Second (Fast)
# 37  1.10 Attacks per Second (Fast)
# 38  1.10 Attacks per Second (Fast)
# 39  1.10 Attacks per Second (Fast)
# 40  1.10 Attacks per Second (Fast)
# 41  1.10 Attacks per Second (Fast)
# 42  1.10 Attacks per Second (Fast)
# 43  1.10 Attacks per Second (Fast)
# 44  1.10 Attacks per Second (Fast)
# 45  1.10 Attacks per Second (Fast)
# 46  1.10 Attacks per Second (Fast)
# 47  1.10 Attacks per Second (Fast)
# 48  1.10 Attacks per Second (Fast)
# 49  1.10 Attacks per Second (Fast)
# 50  1.10 Attacks per Second (Fast)
# 51  1.10 Attacks per Second (Fast)
